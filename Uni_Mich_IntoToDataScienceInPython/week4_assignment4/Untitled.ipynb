# %% [markdown]
# ### direct copy and paste Q1 . fail

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

pd.set_option('display.max_column',None)
pd.set_option('display.max_row',None)

nhl_df=pd.read_csv("assets/nhl.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def nhl_correlation():
    
    nhl_df=pd.read_csv("assets/nhl.csv")
    cities=pd.read_html("assets/wikipedia_data.html")[1]
    cities=cities.iloc[:-1,[0,3,5,6,7,8]]
    
    cities.rename({'Population (2016 est.)[8]':'metropolitan area population'},axis=1,inplace=True)
    cities = cities[['Metropolitan area','metropolitan area population']]
    cities.set_index(['Metropolitan area'],inplace=True)
      
    nhl_df=nhl_df[nhl_df['year']==2018]
    nhl_df=nhl_df[['team','W','L']]
    nhl_df['team'].replace(r'\*',"",regex=True,inplace=True)
    nhl_df.drop([0,9,18,26],inplace=True)
    nhl_df[["W", "L"]] = nhl_df[["W", "L"]].apply(pd.to_numeric)
    nhl_df['Win/Loss'] = nhl_df['W']/(nhl_df['W']+nhl_df['L'])
    list_met=[]
    for met_area in nhl_df['team']:
        list_met.append(met_area)
    list_met.sort()
    nhl_df['team']=list_met
    nhl_df["Metropolitan area"]=["Los Angeles",
    "Phoenix",
    "Boston",
    "Buffalo",
    "Calgary",
    "Raleigh",
    "Chicago",
    "Denver",
    "Columbus",
    np.nan,
    "Detroit",
    "Edmonton",
    "Miami–Fort Lauderdale", 
    "Los Angeles",
    "Minneapolis–Saint Paul", 
    "Montreal",
    np.nan,
    np.nan,
    "New York City",
    "New York City",
    "Ottawa",
    "Philadelphia",
    "Pittsburgh",
    "San Francisco Bay Area",
    "St. Louis",
    "Tampa Bay Area",
    "Toronto",
    "Vancouver",
    "Las Vegas",
    "Washington, D.C.", 
    "Winnipeg"
    ]
    nhl_df.reset_index(inplace=True)
    nhl_df.drop([9,16,17],inplace=True)
    nhl_df.reset_index(inplace=True)
    nhl_df.set_index('Metropolitan area',inplace=True)
    nhl_df.drop(['index','level_0'],axis=1,inplace=True)    
    metro_nhl=pd.merge(cities,nhl_df,how='inner',left_on='Metropolitan area',right_on='Metropolitan area')
    
    ave=(metro_nhl.iloc[0,4]+metro_nhl.iloc[1,4])/2
    metro_nhl.iloc[0,4]=ave
    metro_nhl.iloc[1,4]=ave
    ave2=(metro_nhl.iloc[2,4]+metro_nhl.iloc[3,4])/2
    metro_nhl.iloc[2,4]=ave2
    metro_nhl.iloc[3,4]=ave2
    
    intpop=[]
    for x in metro_nhl['metropolitan area population']:
        intpop.append(int(x))
    metro_nhl['metropolitan area population']=intpop
    
    raise NotImplementedError()
    
    population_by_region = metro_nhl['metropolitan area population'] # pass in metropolitan area population from cities
    win_loss_by_region = metro_nhl['Win/Loss'] # pass in win/loss ratio from nhl_df in the same order as cities["Metropolitan area"]

    assert len(population_by_region) == len(win_loss_by_region), "Q1: Your lists must be the same length"
    assert len(population_by_region) == 28, "Q1: There should be 28 teams being analysed for NHL"
    
    return stats.pearsonr(population_by_region, win_loss_by_region)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-5ed31c232950> in <module>
#       7 pd.set_option('display.max_row',None)
#       8
# ----> 9 nhl_df=pd.read_csv("assets/nhl.csv")
#      10 cities=pd.read_html("assets/wikipedia_data.html")[1]
#      11 cities=cities.iloc[:-1,[0,3,5,6,7,8]]
#
# ...

# %% [markdown]
# ## Q1

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

pd.set_option('display.max_column',None)
pd.set_option('display.max_row',None)


nhl_df = pd.read_csv('nhl.csv')
nhl_df=nhl_df[nhl_df['year']==2018]    
nhl_df=nhl_df[['team','W','L']]
nhl_df['team'].replace(r'\*',"",regex=True,inplace=True)
nhl_df.drop([0,9,18,26],inplace=True)
nhl_df.sort_values(by='team',inplace=True)
nhl_df.reset_index(inplace=True)
nhl_df=nhl_df[['team','W','L']]
nhl_df['team name']=nhl_df['team'].apply(lambda x: x.rsplit(None,1)[-1])
nhl_df.reset_index(inplace=True)
nhl_df=nhl_df[['team','W','L','team name']]
nhl_df['team name'].replace(['Jackets','Wings','Leafs','Knights'],['Blue Jackets',
'Red Wings','Maple Leafs','Golden Knights'],inplace=True)
### Another way ###
#   NHL_df.loc[3,'team_only']='Maple Leaf'
#   NHL_df.loc[5,'team_only']='Red wings'
nhl_df[["W", "L"]] = nhl_df[["W", "L"]].apply(pd.to_numeric)
nhl_df['Win/Loss'] = nhl_df['W']/(nhl_df['W']+nhl_df['L'])

nhl_df.loc[17,'team name']='Rangers Islanders Devils'
nhl_df.loc[18,'team name']='Rangers Islanders Devils'
nhl_df.loc[19,'team name']='Rangers Islanders Devils'

nhl_df.loc[0,'team name']='Kings Ducks'
nhl_df.loc[13,'team name']='Kings Ducks'

##grouping by team name
nhl_df=nhl_df.groupby('team name').mean()
nhl_df.reset_index(inplace=True)

# %%
nhl_df
# Out:
#                    team name          W     L  Win/Loss
# 0                  Avalanche  43.000000  30.0  0.589041
# 1                 Blackhawks  33.000000  39.0  0.458333
# 2               Blue Jackets  45.000000  30.0  0.600000
# 3                      Blues  44.000000  32.0  0.578947
# 4                     Bruins  50.000000  20.0  0.714286
# 5                  Canadiens  29.000000  40.0  0.420290
# 6                    Canucks  31.000000  40.0  0.436620
# 7                   Capitals  49.000000  26.0  0.653333
# 8                    Coyotes  29.000000  41.0  0.414286
# 9                     Flames  37.000000  35.0  0.513889
# 10                    Flyers  42.000000  26.0  0.617647
# 11            Golden Knights  51.000000  24.0  0.680000
# 12                Hurricanes  36.000000  35.0  0.507042
# 13                      Jets  52.000000  20.0  0.722222
# 14               Kings Ducks  44.500000  27.0  0.622895
# 15                 Lightning  54.000000  23.0  0.701299
# ...

# %% [markdown]
# ## Q2

# %%
import pandas as pd
import numpy as ny
pd.set_option('display.max_column',None)
pd.set_option('display.max_row',None)
pd.set_option("display.precision", 15)
nba_df=pd.read_csv('nba.csv')
nba_df=nba_df[nba_df['year']==2018]
nba_df=nba_df[['team','W','L','W/L%']]
nba_df['team'].replace(r'\*.+',"",regex=True,inplace=True)
nba_df['team'].replace(r'\s\(.+',"",regex=True,inplace=True)
nba_df['W/L%']=nba_df['W/L%'].astype('float')
nba_df.reset_index()
nba_df[['team','W','L','W/L%']]
nba_df['team']=nba_df['team'].apply(lambda x: x.rsplit(None,1)[-1])
nba_df['team'].replace(['Blazers','Clippers','Knicks'],['Trail Blazers','LakersClippers','KnicksNets'],inplace=True)
nba_df
# Out:
#               team   W   L   W/L%
# 0          Raptors  59  23  0.720
# 1          Celtics  55  27  0.671
# 2            76ers  52  30  0.634
# 3        Cavaliers  50  32  0.610
# 4           Pacers  48  34  0.585
# 5             Heat  44  38  0.537
# 6            Bucks  44  38  0.537
# 7          Wizards  43  39  0.524
# 8          Pistons  39  43  0.476
# 9          Hornets  36  46  0.439
# 10      KnicksNets  29  53  0.354
# 11            Nets  28  54  0.341
# 12           Bulls  27  55  0.329
# 13           Magic  25  57  0.305
# 14           Hawks  24  58  0.293
# 15         Rockets  65  17  0.793
# 16        Warriors  58  24  0.707
# 17   Trail Blazers  49  33  0.598
# 18         Thunder  48  34  0.585
# 19            Jazz  48  34  0.585
# 20        Pelicans  48  34  0.585
# 21           Spurs  47  35  0.573
# 22    Timberwolves  47  35  0.573
# 23         Nuggets  46  36  0.561
# 24  LakersClippers  42  40  0.512
# 25          Lakers  35  47  0.427
# ...
