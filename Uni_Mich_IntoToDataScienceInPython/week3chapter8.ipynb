# %% [markdown]
# ### Hierarchical

# %%
import pandas as pd
import numpy as np
import random

# %%
data = pd.Series(np.random.randn(9),index=[['a','a','a','b','b','c','c','d','d'],[1,2,3,1,3,1,2,2,3]])

# %%
data
# Out:
# a  1    0.285377
#    2   -0.046855
#    3    0.505592
# b  1   -0.676862
#    3   -1.587692
# c  1   -0.646591
#    2    1.077774
# d  2   -1.165161
#    3    0.887308
# dtype: float64

# %%
data.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
data.loc[:,2]
# Out:
# a   -0.046855
# c    1.077774
# d   -1.165161
# dtype: float64

# %%
data.unstack()
# Out:
#           1         2         3
# a  0.285377 -0.046855  0.505592
# b -0.676862       NaN -1.587692
# c -0.646591  1.077774       NaN
# d       NaN -1.165161  0.887308

# %%
frame = pd.DataFrame(np.arange(12).reshape((4,3)),index=[['a','a','b','b'],[1,2,1,2]], columns=[['Ohio','Ohio','Colorado'],['Green','Red','Green']])

# %%
frame
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.index.names = ['key1','key2']
frame.columns.names = ['state','colour']

# %%
frame
# Out:
# state      Ohio     Colorado
# colour    Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
x =pd.MultiIndex.from_arrays([['Ohio','Ohio','Colorado'],['Green','Red','Green']],names=['state','colour'])

# %%
frame = pd.DataFrame(np.arange(12).reshape((4,3)),index=[['a','a','b','b'],[1,2,1,2]],columns=x)

# %%
frame.index.names = ['key2','key1']
frame
# Out:
# state      Ohio     Colorado
# colour    Green Red    Green
# key2 key1
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %% [markdown]
#   ### Reordering and sorting levels

# %%
frame.swaplevel('key1','key2')
# Out:
# state      Ohio     Colorado
# colour    Green Red    Green
# key1 key2
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %%
frame.sort_index(level=0)
# Out:
# state      Ohio     Colorado
# colour    Green Red    Green
# key2 key1
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.swaplevel(1,0).sort_index(level=0)
# Out:
# state      Ohio     Colorado
# colour    Green Red    Green
# key1 key2
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %%
frame.swaplevel(1,0).sort_index(level=0)
# Out:
# state      Ohio     Colorado
# colour    Green Red    Green
# key1 key2
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %%
frame.sum(level='colour',axis=1)
# Out:
# colour     Green  Red
# key2 key1
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %% [markdown]
# ### Summary Statistical by Level

# %%
frame.sum(level='key1')
# Out:
# state   Ohio     Colorado
# colour Green Red    Green
# key1
# 1          6   8       10
# 2         12  14       16

# %%
frame.sum(level='colour',axis=1)
# Out:
# colour     Green  Red
# key2 key1
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %% [markdown]
# ### 8.2 Combining and Merging Datasets

# %% [markdown]
# ### Database-style DataFrame joins

# %%
df1 = pd.DataFrame({'key':['b','b','a','c','a','a','b'],'data1':range(7)})
df2=pd.DataFrame({'key':['a','b','d'],'data2':range(3)})

# %%
df1
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6

# %%
df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2

# %%
pd.merge(df1,df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
df1 = pd.DataFrame({'lkey':['b','b','a','c','a','a','b'],'data1':range(7)})
df2=pd.DataFrame({'rkey':['a','b','d'],'data2':range(3)})
pd.merge(df1,df2,left_on='lkey',right_on='rkey')
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
pd.merge(df1,df2,how='outer')
# Out:
#   key  data1  data2
# 0   b    0.0    1.0
# 1   b    1.0    1.0
# 2   b    6.0    1.0
# 3   a    2.0    0.0
# 4   a    4.0    0.0
# 5   a    5.0    0.0
# 6   c    3.0    NaN
# 7   d    NaN    2.0

# %%
n = [ x for x in range(3)]
print(n)
# Out:
# [0, 1, 2]

# %%
df1 = pd.DataFrame({'key':['b','b','a','c','a','a','b'],'data1':range(7)})
df2=pd.DataFrame({'key':['a','b','d'],'data2':range(3)})

pd.merge(df1,df2, on='key', how='left')
# Out:
#   key  data1  data2
# 0   b      0    1.0
# 1   b      1    1.0
# 2   a      2    0.0
# 3   c      3    NaN
# 4   a      4    0.0
# 5   a      5    0.0
# 6   b      6    1.0

# %%
df1 = pd.DataFrame({'key':['b','b','a','c','a','a','b'],'data1':range(7)})
df2=pd.DataFrame({'key':['a','b','d'],'data2':range(3)})
pd.merge(df1,df2, on='key', how='outer')
# Out:
#   key  data1  data2
# 0   b    0.0    1.0
# 1   b    1.0    1.0
# 2   b    6.0    1.0
# 3   a    2.0    0.0
# 4   a    4.0    0.0
# 5   a    5.0    0.0
# 6   c    3.0    NaN
# 7   d    NaN    2.0

# %% [markdown]
# ### Merging index

# %%
left1=pd.DataFrame({'key1':['a','b','a','a','b','c'],'value':range(6)})
left1
# Out:
#   key1  value
# 0    a      0
# 1    b      1
# 2    a      2
# 3    a      3
# 4    b      4
# 5    c      5

# %%
right1=pd.DataFrame({'group_val':[3.5,7]},index=['a','b'])
right
# Out:
#    group_val
# a        3.5
# b        7.0

# %%
pd.merge(left1,right1,left_on='key1',right_index=True,how='right')
# Out:
#   key1  value  group_val
# 0    a      0        3.5
# 2    a      2        3.5
# 3    a      3        3.5
# 1    b      1        7.0
# 4    b      4        7.0

# %%
pd.merge(left1,right1,left_on='key1',right_index=True,how='outer')
# Out:
#   key1  value  group_val
# 0    a      0        3.5
# 2    a      2        3.5
# 3    a      3        3.5
# 1    b      1        7.0
# 4    b      4        7.0
# 5    c      5        NaN

# %%
lefth=pd.DataFrame({'key1':['Ohio','Ohio','Ohio','Nevada','Nevada'],'key2':[2000,2001,2002,2001,2002],'data':np.arange(5.)})
lefth
# Out:
#      key1  key2  data
# 0    Ohio  2000   0.0
# 1    Ohio  2001   1.0
# 2    Ohio  2002   2.0
# 3  Nevada  2001   3.0
# 4  Nevada  2002   4.0

# %%
righth=pd.DataFrame(np.arange(12).reshape((6,2)),index=[['Nevada','Nevada','Ohio','Ohio','Ohio','Ohio'],[2001,2000,2000,2000,2001,2002]],columns=['event1','event2'])
righth
# Out:
#              event1  event2
# Nevada 2001       0       1
#        2000       2       3
# Ohio   2000       4       5
#        2000       6       7
#        2001       8       9
#        2002      10      11

# %%
pd.merge(lefth,righth,left_on=['key1','key2'],right_index=True, how='outer')
# Out:
#      key1  key2  data  event1  event2
# 0    Ohio  2000   0.0     4.0     5.0
# 0    Ohio  2000   0.0     6.0     7.0
# 1    Ohio  2001   1.0     8.0     9.0
# 2    Ohio  2002   2.0    10.0    11.0
# 3  Nevada  2001   3.0     0.0     1.0
# 4  Nevada  2002   4.0     NaN     NaN
# 4  Nevada  2000   NaN     2.0     3.0

# %%
righth.join(lefth=['key1','key2'],how='outer')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-696f3166eeab> in <module>
# ----> 1 righth.join(lefth=['key1','key2'],how='outer')
#
# TypeError: join() got an unexpected keyword argument 'lefth'

# %%
left1=pd.DataFrame({'key1':['a','b','c','d','e','f','g','h','i'],'value':range(9)})
right1=pd.DataFrame({'key1':['a','b','c','d','e','f','g','h','i'],'value':range(9)})

# %%
type(right1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(left1)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.concat(right1,left1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-d6c062b7c807> in <module>
# ----> 1 pd.concat(right1,left1)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     318     ):
#     319         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> 320             raise TypeError(
#     321                 "first argument must be an iterable of pandas "
# ...

# %% [markdown]
# ### Concatenate Along an Axis

# %%
s1 = pd.Series([0,1],index=['a','b'])
s2 = pd.Series([2,3,4],index=['c','d','e'])
s3 = pd.Series([5,6,],index=['f','g'])

# %%
pd.concat([s1,s2,s3], axis=1)
# Out:
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
df1=pd.DataFrame(np.arange(6).reshape(3,2), index=['a','b','c'],columns=['one','two'])
df2=pd.DataFrame(5+np.arange(4).reshape(2,2),index=['a','c'],columns=['three','four'])

# %%
pd.concat({'level1':df1,'level2':df2},axis=1)
# Out:
#   level1     level2
#      one two  three four
# a      0   1    5.0  6.0
# b      2   3    NaN  NaN
# c      4   5    7.0  8.0

# %%
pd.concat([df1,df2],axis=1,keys=['level1','level2'],names=['upper','lower'])
# Out:
# upper level1     level2
# lower    one two  three four
# a          0   1    5.0  6.0
# b          2   3    NaN  NaN
# c          4   5    7.0  8.0

# %%
df1=pd.DataFrame(np.random.randn(3,4),index=['tom','jerry','buster'],columns=['a','b','c','d'])
df2=pd.DataFrame(np.random.randn(2,3),columns=['b','d','a'])

# %%
pd.concat([df1,df2])
# Out:
#                a         b         c         d
# tom    -0.337036 -0.368208  1.412771 -0.091833
# jerry  -0.528358 -0.625538 -1.577974 -0.343151
# buster  0.593799  1.676812 -0.701468 -0.185154
# 0       0.363387  0.469801       NaN  0.208885
# 1       0.989506 -2.173453       NaN -0.295192

# %%
pd.concat([df1,df2],ignore_index=False)
# Out:
#                a         b         c         d
# tom    -0.337036 -0.368208  1.412771 -0.091833
# jerry  -0.528358 -0.625538 -1.577974 -0.343151
# buster  0.593799  1.676812 -0.701468 -0.185154
# 0       0.363387  0.469801       NaN  0.208885
# 1       0.989506 -2.173453       NaN -0.295192

# %%
a = pd.Series([np.nan,2.5,0.0,3.5,4.5,np.nan],index=['f','e','d','c','d','a'])

# %%
b = pd.Series([0.,np.nan, 2.,np.nan,np.nan,5.], index=['a','b','c','d','e','f'])

# %%
np.where(pd.isnull(a
                  
                  a),b,a)
# Out:
# array([0. , 2.5, 0. , 3.5, 4.5, 5. ])

# %%
data = pd.DataFrame(np.arange(6).reshape((2,3)),)
